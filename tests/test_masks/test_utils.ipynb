# %%
# %load_ext autoreload
# %autoreload 2

# %%
import torch

from nichejepa.masks.utils import apply_masks

# %%
x = torch.rand(2, 5, 4)
masks = [torch.tensor([[0, 1, 3], [1, 2, 4]]), torch.tensor([[0, 1, 2], [1, 3, 4]]), torch.tensor([[0, 1, 4], [0, 2, 3]])]

# %%
x
# Out:
# tensor([[[0.1405, 0.6006, 0.3743, 0.7829],
#          [0.9370, 0.0897, 0.3476, 0.7266],
#          [0.0071, 0.4613, 0.9031, 0.1950],
#          [0.8604, 0.8793, 0.8406, 0.8541],
#          [0.3900, 0.0831, 0.1157, 0.1542]],
#
#         [[0.3215, 0.7301, 0.5791, 0.8363],
#          [0.4243, 0.2179, 0.2720, 0.3998],
#          [0.9271, 0.2360, 0.0611, 0.7351],
#          [0.4559, 0.4516, 0.9540, 0.6019],
#          [0.6978, 0.2790, 0.8142, 0.8258]]])

# %%
mask_out = apply_masks(x, masks)
print(mask_out.shape)
print(mask_out)
# Out:
# torch.Size([6, 3, 4])
# tensor([[[0.1405, 0.6006, 0.3743, 0.7829],
#          [0.9370, 0.0897, 0.3476, 0.7266],
#          [0.8604, 0.8793, 0.8406, 0.8541]],
#
#         [[0.4243, 0.2179, 0.2720, 0.3998],
#          [0.9271, 0.2360, 0.0611, 0.7351],
#          [0.6978, 0.2790, 0.8142, 0.8258]],
#
#         [[0.1405, 0.6006, 0.3743, 0.7829],
#          [0.9370, 0.0897, 0.3476, 0.7266],
#          [0.0071, 0.4613, 0.9031, 0.1950]],
#
#         [[0.4243, 0.2179, 0.2720, 0.3998],
#          [0.4559, 0.4516, 0.9540, 0.6019],
#          [0.6978, 0.2790, 0.8142, 0.8258]],
#
#         [[0.1405, 0.6006, 0.3743, 0.7829],
#          [0.9370, 0.0897, 0.3476, 0.7266],
#          [0.3900, 0.0831, 0.1157, 0.1542]],
#
#         [[0.3215, 0.7301, 0.5791, 0.8363],
#          [0.9271, 0.2360, 0.0611, 0.7351],
#          [0.4559, 0.4516, 0.9540, 0.6019]]])
